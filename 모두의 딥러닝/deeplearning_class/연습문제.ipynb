# %%
for i in range(2,10):
    for j in range(1,10):
        print(i," * ", j," = ", i*j)
# Out:
# 2  *  1  =  2
# 2  *  2  =  4
# 2  *  3  =  6
# 2  *  4  =  8
# 2  *  5  =  10
# 2  *  6  =  12
# 2  *  7  =  14
# 2  *  8  =  16
# 2  *  9  =  18
# 3  *  1  =  3
# 3  *  2  =  6
# 3  *  3  =  9
# 3  *  4  =  12
# 3  *  5  =  15
# 3  *  6  =  18
# 3  *  7  =  21
# 3  *  8  =  24
# 3  *  9  =  27
# 4  *  1  =  4
# 4  *  2  =  8
# 4  *  3  =  12
# 4  *  4  =  16
# 4  *  5  =  20
# 4  *  6  =  24
# 4  *  7  =  28
# 4  *  8  =  32
# 4  *  9  =  36
# 5  *  1  =  5
# 5  *  2  =  10
# 5  *  3  =  15
# 5  *  4  =  20
# 5  *  5  =  25
# 5  *  6  =  30
# 5  *  7  =  35
# 5  *  8  =  40
# 5  *  9  =  45
# 6  *  1  =  6
# 6  *  2  =  12
# 6  *  3  =  18
# 6  *  4  =  24
# 6  *  5  =  30
# 6  *  6  =  36
# 6  *  7  =  42
# 6  *  8  =  48
# 6  *  9  =  54
# 7  *  1  =  7
# 7  *  2  =  14
# 7  *  3  =  21
# 7  *  4  =  28
# 7  *  5  =  35
# 7  *  6  =  42
# 7  *  7  =  49
# 7  *  8  =  56
# 7  *  9  =  63
# 8  *  1  =  8
# 8  *  2  =  16
# 8  *  3  =  24
# 8  *  4  =  32
# 8  *  5  =  40
# ...

# %%
import random
lotto = random.sample(range(1,46),7)

print(lotto[:6])
print("bonus : ",lotto[-1] )
# Out:
# [8, 45, 26, 34, 27, 38]
# bonus :  32

# %%
import matplotlib.font_manager as fm
import platform
 
if platform.system() =='Windows':
    font_path = 'C:/Windows/Fonts/gulim.ttc' #윈도우 굴림폰트
elif platform.system() == 'Linux':    #우분투 18.04 테스트됨, 나눔폰트 설치 후
    font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
     
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = font_name
plt.rcParams['font.size'] = 12

# %%
import pandas as pd
csv_test = pd.read_csv('2019_프로야구_타자20.csv')
csv_test
# Out:
#     순번     이름   팀명     타율  경기수   타수   안타  2루타  3루타  홈런   타점   득점  도루  볼넷   삼진  \
# 0    1    양의지   NC  0.354  118  390  138   26    0  20   68   61   4  48   43
# 1    2  페르난데스   두산  0.344  144  572  197   34    0  15   88   87   1  61   54
# 2    3    박민우   NC  0.344  125  468  161   23    8   1   45   89  18  41   40
# 3    4    이정후   키움  0.336  140  574  193   31   10   6   68   91  13  45   40
# 4    5    강백호   KT  0.336  116  438  147   29    1  13   65   72   9  61   87
# 5    6    고종욱   SK  0.323  137  492  159   25    7   3   56   76  31  18   89
# 6    7    로하스   KT  0.322  142  521  168   30    3  24  104   68   4  49  120
# 7    8    박건우   두산  0.319  127  458  146   27    5  10   64   83  12  60   57
# 8    9    유한준   KT  0.317  139  501  159   19    1  14   86   61   3  52   61
# 9   10    채은성   LG  0.315  128  470  148   18    1  12   72   59   2  24   67
# 10  11    이천웅   LG  0.308  138  546  168   24    3   2   48   88  21  57   82
# ...

# %%
df = csv_test[['이름','홈런']]
df2 = df.sort_values(by=['홈런'],ascending=False)
df3 = df2.set_index('이름')
df3
# Out:
#        홈런
# 이름
#  샌즈    28
#  로하스   24
#  전준우   22
# 양의지    20
#  김하성   19
#  최형우   17
# 페르난데스  15
#  유한준   14
#  강백호   13
#  채은성   12
#  김현수   11
#  손아섭   10
#  박건우   10
#  김태균    6
#  이정후    6
#  김헌곤    5
#  고종욱    3
#  서건창    2
#  이천웅    2
#  박민우    1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
ax = df3.head().plot(kind='bar')
ax.set_title('상위 5명의 타자 홈런')
plt.xlabel('player')
# Out:
# Text(0.5, 0, 'player')

# %%
plt.pie(df3['홈런'], labels = df3['이름'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\dev\Anaconda3\envs\Keras\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '이름'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-ebcd4523c6b0> in <module>
# ...
